# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Importando os dados do Excel
df = pd.read_excel('vendas_eletos_eletronicos2.xlsx')

# Medidas de Posição
# Medidas de Tendência Central
media_preco = np.mean(df['Total'])
mediana_preco = np.median(df['Total'])

# Obtendo os Quartis
q1 = np.percentile(df['Total'], 25)
q2 = np.percentile(df['Total'], 50)
q3 = np.percentile(df['Total'], 75)

# Filtrando os produtos com vendas superiores a 10 unidades
produtos_mais_vendidos = df[df['Total'] > q3]

# Exibindo os resultados
print(70*'_')
print(f'\nMEDIDAS DE TENDÊNCIA CENTRAL')
print(f"Média dos preços: R$ {media_preco:.2f}")
print(f"Mediana dos preços: R$ {mediana_preco:.2f}")

print(70*'_')
print(f'\nANÁLISE DOS VALORES: QUARTIS')
print(f"25% das vendas tiveram o valor total arrecadado até: R$ {q1:.2f}")
print(f"50% arrecadação total dos produtos vendidos foram abaixo ou iguais a: R$ {q2:.2f}")
print(f"75% do total das vendas ficaram abaixo de: R$ {q3:.2f}")

print(70*'_')
print(f'\nPRODUTOS MAIS VENDIDOS: QUARTIL')
print(produtos_mais_vendidos[['Nome do Produto', 'Total']].sort_values(by='Total', ascending=False))

# Definindo o tamanho da figura do gráfico (10 de largura e 6 de altura)
plt.figure(figsize=(10, 6))

# Ordenando os produtos mais vendidos em ordem decrescente pelo total de vendas
# e criando um gráfico de barras com o 'Nome do Produto' no eixo X e o 'Total' no eixo Y
produtos_mais_vendidos.sort_values(by='Total', ascending=False).plot(
    kind='bar',   # Tipo de gráfico: barra
    x='Nome do Produto',  # Eixo horizontal mostra os nomes dos produtos
    y='Total'  # Eixo vertical mostra o total das vendas
)

# Exibindo o gráfico na tela
plt.show
# Out:
# ______________________________________________________________________
#
# MEDIDAS DE TENDÊNCIA CENTRAL
# Média dos preços: R$ 30490.90
# Mediana dos preços: R$ 18862.50
# ______________________________________________________________________
#
# ANÁLISE DOS VALORES: QUARTIS
# 25% das vendas tiveram o valor total arrecadado até: R$ 10960.00
# 50% arrecadação total dos produtos vendidos foram abaixo ou iguais a: R$ 18862.50
# 75% do total das vendas ficaram abaixo de: R$ 49746.75
# ______________________________________________________________________
#
# PRODUTOS MAIS VENDIDOS: QUARTIL
#     Nome do Produto  Total
# 3          Notebook  94500
# 2        Smartphone  76000
# 1      Smart TV 55"  72000
# 17  Ar Condicionado  66000
# 11        Geladeira  51987
